# %%
import pandas as pd
import numpy as np

# %%
players = {'Name':['Avery Bradley', 'John Holland','Jonas Jeberko','Jordon Mickey','Terry Rozier','Jared Sullinger','Evan Turner'],
           'Team':['Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics'],
           'Number': [0.0 , 30.0 , 8.0 , np.nan , 12.0 , 7.0 , 11.0 ],
           'Position':['PG','SG','PF','PF','PG','C','SG'],
           'Age':[25.0,27.0,29.0,21.0,22.0,np.nan,27.0]}
players
# Out:
# {'Name': ['Avery Bradley',
#   'John Holland',
#   'Jonas Jeberko',
#   'Jordon Mickey',
#   'Terry Rozier',
#   'Jared Sullinger',
#   'Evan Turner'],
#  'Team': ['Boston Celtics',
#   'Boston Celtics',
#   'Boston Celtics',
#   'Boston Celtics',
#   'Boston Celtics',
#   'Boston Celtics',
#   'Boston Celtics'],
#  'Number': [0.0, 30.0, 8.0, nan, 12.0, 7.0, 11.0],
#  'Position': ['PG', 'SG', 'PF', 'PF', 'PG', 'C', 'SG'],
#  'Age': [25.0, 27.0, 29.0, 21.0, 22.0, nan, 27.0]}

# %%
players = pd.DataFrame(players)
players
# Out:
#               Name            Team  Number Position   Age
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0
# 1     John Holland  Boston Celtics    30.0       SG  27.0
# 2    Jonas Jeberko  Boston Celtics     8.0       PF  29.0
# 3    Jordon Mickey  Boston Celtics     NaN       PF  21.0
# 4     Terry Rozier  Boston Celtics    12.0       PG  22.0
# 5  Jared Sullinger  Boston Celtics     7.0        C   NaN
# 6      Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
student= {'Name':['Jack', 'Riti','Tom','Neelu','John','Mike'],
          'Age':[34,30,31,32,16,17],
          'City': ['Sydney','Delhi','Mumbai','Banglore','New York','Las Vegas'],
          'Country':['Australia','India','India','India','US','US'],
          'Course':['Computer Science','Computer Science','Computer Science','Computer Science','Computer Science','Computer Science'],
          'Grade':['A','A','A','A','A','A']}
student
# Out:
# {'Name': ['Jack', 'Riti', 'Tom', 'Neelu', 'John', 'Mike'],
#  'Age': [34, 30, 31, 32, 16, 17],
#  'City': ['Sydney', 'Delhi', 'Mumbai', 'Banglore', 'New York', 'Las Vegas'],
#  'Country': ['Australia', 'India', 'India', 'India', 'US', 'US'],
#  'Course': ['Computer Science',
#   'Computer Science',
#   'Computer Science',
#   'Computer Science',
#   'Computer Science',
#   'Computer Science'],
#  'Grade': ['A', 'A', 'A', 'A', 'A', 'A']}

# %%
student = pd.DataFrame(student)
student
# Out:
#     Name  Age       City    Country            Course Grade
# 0   Jack   34     Sydney  Australia  Computer Science     A
# 1   Riti   30      Delhi      India  Computer Science     A
# 2    Tom   31     Mumbai      India  Computer Science     A
# 3  Neelu   32   Banglore      India  Computer Science     A
# 4   John   16   New York         US  Computer Science     A
# 5   Mike   17  Las Vegas         US  Computer Science     A

# %%
players.shape
# Out:
# (7, 5)

# %%
pd.DataFrame(players,index=[2,4,6])
# Out:
#             Name            Team  Number Position   Age
# 2  Jonas Jeberko  Boston Celtics     8.0       PF  29.0
# 4   Terry Rozier  Boston Celtics    12.0       PG  22.0
# 6    Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
players['Name']
# Out:
# 0      Avery Bradley
# 1       John Holland
# 2      Jonas Jeberko
# 3      Jordon Mickey
# 4       Terry Rozier
# 5    Jared Sullinger
# 6        Evan Turner
# Name: Name, dtype: object

# %%
players['Age']
# Out:
# 0    25.0
# 1    27.0
# 2    29.0
# 3    21.0
# 4    22.0
# 5     NaN
# 6    27.0
# Name: Age, dtype: float64

# %%
players[['Name','Number']]
# Out:
#               Name  Number
# 0    Avery Bradley     0.0
# 1     John Holland    30.0
# 2    Jonas Jeberko     8.0
# 3    Jordon Mickey     NaN
# 4     Terry Rozier    12.0
# 5  Jared Sullinger     7.0
# 6      Evan Turner    11.0

# %%
players.query('Position=="SG" ')
# Out:
#            Name            Team  Number Position   Age
# 1  John Holland  Boston Celtics    30.0       SG  27.0
# 6   Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
players[players.Name.str.startswith('J')]
# Out:
#               Name            Team  Number Position   Age
# 1     John Holland  Boston Celtics    30.0       SG  27.0
# 2    Jonas Jeberko  Boston Celtics     8.0       PF  29.0
# 3    Jordon Mickey  Boston Celtics     NaN       PF  21.0
# 5  Jared Sullinger  Boston Celtics     7.0        C   NaN

# %%
players.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# dtype: object

# %%
players.__sizeof__()
# Out:
# 1637

# %%
players['Name'].value_counts()
# Out:
# Name
# Avery Bradley      1
# John Holland       1
# Jonas Jeberko      1
# Jordon Mickey      1
# Terry Rozier       1
# Jared Sullinger    1
# Evan Turner        1
# Name: count, dtype: int64

# %%
players['Team'].value_counts()
# Out:
# Team
# Boston Celtics    7
# Name: count, dtype: int64

# %%
players.isnull()
# Out:
#     Name   Team  Number  Position    Age
# 0  False  False   False     False  False
# 1  False  False   False     False  False
# 2  False  False   False     False  False
# 3  False  False    True     False  False
# 4  False  False   False     False  False
# 5  False  False   False     False   True
# 6  False  False   False     False  False

# %%
student.query("Country=='Australia'")
# Out:
#    Name  Age    City    Country            Course Grade
# 0  Jack   34  Sydney  Australia  Computer Science     A

# %%
student.head(3)
# Out:
#    Name  Age    City    Country            Course Grade
# 0  Jack   34  Sydney  Australia  Computer Science     A
# 1  Riti   30   Delhi      India  Computer Science     A
# 2   Tom   31  Mumbai      India  Computer Science     A

# %%
student.tail(3)
# Out:
#     Name  Age       City Country            Course Grade
# 3  Neelu   32   Banglore   India  Computer Science     A
# 4   John   16   New York      US  Computer Science     A
# 5   Mike   17  Las Vegas      US  Computer Science     A

# %%
student.sample()
# Out:
#   Name  Age    City Country            Course Grade
# 2  Tom   31  Mumbai   India  Computer Science     A

# %%
players.dropna()
# Out:
#             Name            Team  Number Position   Age
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0
# 1   John Holland  Boston Celtics    30.0       SG  27.0
# 2  Jonas Jeberko  Boston Celtics     8.0       PF  29.0
# 4   Terry Rozier  Boston Celtics    12.0       PG  22.0
# 6    Evan Turner  Boston Celtics    11.0       SG  27.0

# %%
student[student.Age==32]
# Out:
#     Name  Age      City Country            Course Grade
# 3  Neelu   32  Banglore   India  Computer Science     A

# %%
players.Number.nlargest()
# Out:
# 1    30.0
# 4    12.0
# 6    11.0
# 2     8.0
# 5     7.0
# Name: Number, dtype: float64

# %%
student.drop(index=[2,4])
# Out:
#     Name  Age       City    Country            Course Grade
# 0   Jack   34     Sydney  Australia  Computer Science     A
# 1   Riti   30      Delhi      India  Computer Science     A
# 3  Neelu   32   Banglore      India  Computer Science     A
# 5   Mike   17  Las Vegas         US  Computer Science     A

# %%
student[student.City.apply(len)>7]
# Out:
#     Name  Age       City Country            Course Grade
# 3  Neelu   32   Banglore   India  Computer Science     A
# 4   John   16   New York      US  Computer Science     A
# 5   Mike   17  Las Vegas      US  Computer Science     A
