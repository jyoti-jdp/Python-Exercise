# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
#1. Write a Python program to sum all the items in a list.
l1 = (input('Enter list: ')).split()
total = 0
for i in range(len(l1)):
    total = total + int(l1[i])
print(total)
# Out:
# Enter list: 50 4 5  6 8 3 1 8
# 85

# %%
l1 = (input('Enter list: ')).split()
mul = 1
for i in range(len(l1)):
    if int(l1[i])>len(l1):
        mul=mul*int(l1[i])
print(mul)
# Out:
# Enter list: 50 6 7
# 2100

# %%
# 3. Write a Python program to get the largest number from a list.
l1 = (input('Enter list: ')).split()
l1.sort()
l1[-1]
# Out:
# Enter list: 5 6 87 49 25 68 89
# '89'

# %%
# 5. Write a Python program to count the number of strings where the string length
# is 2 or more and the first and last character are same from a given list of strings.
# Sample List : ['abc', 'xyz', 'aba', '1221']
l2 = (input('Enter list: ')).split()
l2_n = []
for i in l2:
    if i[0] == i[-1] and len(i)>=2:
       l2_n.append(i)
print(l2_n)
# Out:
# Enter list: aba abc 1221 656
# ['aba', '1221', '656']

# %%
# 6. Write a Python program to get a list, sorted in increasing order by the last element in each tuple from a given list of non-empty tuples.
def Sort_Tuple(tup):

    # getting length of list of tuples
    lst = len(tup)
    for i in range(0, lst):

        for j in range(0, lst-i-1):
            if (tup[j][-1] > tup[j + 1][-1]):
                temp = tup[j]
                tup[j]= tup[j + 1]
                tup[j + 1]= temp
    return tup
Sort_Tuple([(1, 3), (3, 2), (2, 1),(5,9),(2,8)])
# Out:
# [(2, 1), (3, 2), (1, 3), (2, 8), (5, 9)]

# %%
# 7. Write a Python program to remove duplicates from a list.
s = [54,65,36,32,5,6,54,36]
s1 =[]
for i in range(len(s)):
        if s[i] not in s1:
            s1.append(s[i])
print(s1)
# Out:
# [54, 65, 36, 32, 5, 6]

# %%
# 8. Write a Python program to check a list is empty or not.
s =[]
s is True
# Out:
# False

# %%
# 9. Write a Python program to clone or copy a list.
s = [12,14,15,16,13,74]
s1 = s.copy()
s1
# Out:
# [12, 14, 15, 16, 13, 74]

# %%
print(id(s))
print(id(s1))
# Out:
# 133094187141888
# 133094127578880

# %%
# 10. Write a Python program to find the list of words that are longer than n from a given list of words.
a = (input('Enter List: ')).split()
n = int(input('Enter No.: '))
a1 =[]
for i in a:
    if len(i) > n:
        a1.append(i)
print(a1)
# Out:
# Enter List: The code is trying to remove duplicates from a list by iterating through it and comparing each element to the rest
# Enter No.: 4
# ['trying', 'remove', 'duplicates', 'iterating', 'through', 'comparing', 'element']

# %%
# 11. Write a Python function that takes two lists and returns True if they have at least one common member.
def common_member(a, b):
    for i in a:
        for j in b:
            if i == j:
                return True
    return False
a = (input('Enter List: ')).split()
b = (input('Enter List: ')).split()
common_member(a, b)
# Out:
# Enter List: The code is trying to remove duplicates from a list by iterating through it and comparing each element to the rest. However, it modifies the list while iterating, which causes the IndexError
# Enter List: Write a Python function that takes two lists and returns True if they have at least one common member
# True

# %%
# 12. Write a Python program to print a specified list after removing the 0th, 4th and 5th elements.
a = [54,65,36,32,5,6,54,36]
a.remove(a[5])
a.remove(a[4])
a.remove(a[0])

# %%
a
# Out:
# [65, 36, 32, 54, 36]

# %%
[[['*' for col in range(3)] for col in range(4)] for row in range(6)]
# Out:
# [[['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*']],
#  [['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*']],
#  [['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*']],
#  [['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*']],
#  [['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*']],
#  [['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*'], ['*', '*', '*']]]

# %%
# 14. Write a Python program to print the numbers of a specified list after removing even numbers from it.
def remove_even(lst):
    lst_1 =[]
    for i in lst:
        if i%2 !=0:
            lst_1.append(i)
    return lst_1
lst = [44,65,22,54,65,36,32,5,6,54,36]
remove_even(lst)
# Out:
# [65, 65, 5]

# %%
# 16. Write a Python program to generate and print a list of first and last 5 elements where the values are square of numbers between 1 and 30 (both included).
def first_last_5():
    lst_1 =[]
    for i in range(1,31):
        if i < 6 or 25<i<31:
            lst_1.append(i**2)

    return lst_1
first_last_5()
# Out:
# [1, 4, 9, 16, 25, 676, 729, 784, 841, 900]

# %%
# 17. Write a Python program to generate and print a list except for the first 5 elements, where the values are square of numbers between 1 and 30 (both included).
def first_last_5leave():
    l = []
    for i in range(1,30):
        if 5<i<26 :
            l.append(i**2)
    return l
first_last_5leave()
# Out:
# [36,
#  49,
#  64,
#  81,
#  100,
#  121,
#  144,
#  169,
#  196,
#  225,
#  256,
#  289,
#  324,
#  361,
#  400,
#  441,
#  484,
#  529,
#  576,
#  625]

# %%
# 19. Write a Python program to get the difference between the two lists.
def difference(a,b):
    lst =[]
    (for i in a) not in b:
        lst.append[i]
    return lst
a= [44,65,22,54,65,36,32,5,6,54,36]
b =[2,56,21,22,54,65,36,78,98,5]
difference(a,b)
# Out:
#   File "<ipython-input-4-80afba1836d8>", line 4
#     (for i in a) not in b:
#      ^
# SyntaxError: invalid syntax

# %%
person = {"name": "Jessa", 'country': "USA", "telephone": 1178}

# update dictionary by adding 2 new keys
person["weight"] = 50
person.update({"height": 6, 'Add':'Pune'})
person
# Out:
# {'name': 'Jessa',
#  'country': 'USA',
#  'telephone': 1178,
#  'weight': 50,
#  'height': 6,
#  'Add': 'Pune'}
