# %%
# Write a Python script to add a key to a dictionary.
d = {1:50,2:25,3:100}
d.update({5:40})

# %%
d
# Out:
# {1: 50, 2: 25, 3: 100, 5: 40}

# %%
# Write a Python script to concatenate the following dictionaries to create a new one.
a = {1:20, 2:30}
b = {3:60, 4:10}
c = {5:40, 6:70}
f = {}
for i in (a,b,c):
    f.update(i)
print(f)
# Out:
# {1: 20, 2: 30, 3: 60, 4: 10, 5: 40, 6: 70}

# %%
 # Write a Python script to check whether a given key already exists in a dictionary.
s = {'name':'Jyoti','Age':29,'Qualification':'B.E.'}
if 'Age' in s:
    print('Key is present')
else:
    print('key not present')
# Out:
# Key is present

# %%
# Write a Python program to iterate over dictionaries using for loop
a={1: 50, 2: 25, 3: 100, 5: 40}
for i,j in d.items():
    print(i,'=',i*j)
# Out:
# 1 = 50
# 2 = 50
# 3 = 300
# 5 = 200

# %%
# Write a Python script to generate and print a dictionary that contains a numbers (between 1 and n) in the form (x, x*x). Sample Dictionary ( n = 5) :
def sq_rt_dict(n):
    s={}
    for x in range(1,n+1):
        s.update({x:x*x})
    return s
sq_rt_dict(7)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49}

# %%
# 8. Write a Python script to merge two Python dictionaries.
d1 = {'a':100,'b':200}
d2 = {'x':300,'y':400}
d1.update(d2)

# %%
d1
# Out:
# {'a': 100, 'b': 200, 'x': 300, 'y': 400}

# %%
# Write a Python program to iterate over dictionaries using for loops.
c = {1: 20, 2: 30, 3: 60, 4: 10, 5: 40, 6: 70}
for i in c:
    c[i]=c[i]+50
print(c)
# Out:
# {1: 70, 2: 80, 3: 110, 4: 60, 5: 90, 6: 120}

# %%
# Write a  Python program to sum all the items in a dictionary.
dict_1 = {'data1':100,'data2':200,'data3':300}
result = sum(dict_1.values())
result
# Out:
# 600

# %%
dict_1 = {'data1':10,'data2':20,'data3':30}
result = 1
for keys in dict_1:
    result=result*dict_1[keys]
print(result)
# Out:
# 6000

# %%
# Write a Python program to remove a key from a dictionary.
c = {1: 20, 2: 30, 3: 60, 4: 10, 5: 40, 6: 70}
c.pop(4)
# Out:
# 10

# %%
# Write a Python program to map two lists into a dictionary.
keys = ['Animal','Bird','Tree','Flower']
values =['Lion','Peacock','Banayan','Mogra']
dict(zip(keys,values))
# Out:
# {'Animal': 'Lion', 'Bird': 'Peacock', 'Tree': 'Banayan', 'Flower': 'Mogra'}

# %%
# Write a Python program to sort a given dictionary by key.
h = {'Animal': ['Lion','Tiger'], 'Bird': ['Peacock','Sparrow'], 'Tree': ['Banayan','Peepal'], 'Flower': ['Mogra','Rose']}
dict(sorted(h.items()))
# Out:
# {'Animal': ['Lion', 'Tiger'],
#  'Bird': ['Peacock', 'Sparrow'],
#  'Flower': ['Mogra', 'Rose'],
#  'Tree': ['Banayan', 'Peepal']}

# %%
# Write a Python program to sort a given dictionary by value.
dict(sorted(h.items(),key = lambda item:item[1]))
# Out:
# {'Tree': ['Banayan', 'Peepal'],
#  'Animal': ['Lion', 'Tiger'],
#  'Flower': ['Mogra', 'Rose'],
#  'Bird': ['Peacock', 'Sparrow']}

# %%
dict(sorted(h.items(),key = lambda item:item[1][1])) # Python program to sort a given dictionary by 2nd value
# Out:
# {'Tree': ['Banayan', 'Peepal'],
#  'Flower': ['Mogra', 'Rose'],
#  'Bird': ['Peacock', 'Sparrow'],
#  'Animal': ['Lion', 'Tiger']}

# %%
# Write a Python program to get the maximum and minimum values of a dictionary.
c = {1: 20, 2: 30, 3: 60, 4: 10, 5: 40, 6: 70}
print('Minimum value is: ', min(c.values()))
print('Minimum value is: ',max(c.values()))
# Out:
# 10
# 70

# %%
# Write a Python program to remove duplicates from the dictionary.
student_data = {'id1': {'name': ['Sara'], 'class': ['V'],
                        'subject_integration': ['english, math, science']},
                'id2': {'name': ['David'], 'class': ['V'],
                        'subject_integration': ['english, math, science']},
                'id3': {'name': ['Sara'], 'class': ['V'],
                        'subject_integration': ['english, math, science']},
                'id4': {'name': ['Surya'], 'class': ['V'],
                        'subject_integration': ['english, math, science']}}
std={}
for i,j in student_data.items():
    if j not in std.values():
        std.update({i:j})
std
# Out:
# {'id1': {'name': ['Sara'],
#   'class': ['V'],
#   'subject_integration': ['english, math, science']},
#  'id2': {'name': ['David'],
#   'class': ['V'],
#   'subject_integration': ['english, math, science']},
#  'id4': {'name': ['Surya'],
#   'class': ['V'],
#   'subject_integration': ['english, math, science']}}
